# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# Will not get any warnings when running the code
import warnings
warnings.filterwarnings('ignore')

# %%
# pd = pandas library
ipl = pd.read_csv('D:\Chashira\Projects\IPL 2022 Analytics\IPL_2022_Player_Auction.csv')

# %%
# Explore dataset
ipl.head
# Out:
# <bound method NDFrame.head of      Unnamed: 0                  Player  Base Price         TYPE  \
# 0             0             Rashid Khan  Draft Pick       BOWLER
# 1             1           Hardik Pandya  Draft Pick  ALL-ROUNDER
# 2             2         Lockie Ferguson        2 Cr       BOWLER
# 3             3           Rahul Tewatia     40 Lakh  ALL-ROUNDER
# 4             4            Shubman Gill  Draft Pick       BATTER
# ..          ...                     ...         ...          ...
# 628         628            Sairaj Patil     20 Lakh       BATTER
# 629         629              Monu Singh     20 Lakh       BOWLER
# 630         630  Nivethan Radhakrishnan     20 Lakh       BOWLER
# 631         631            Lance Morris     20 Lakh       BOWLER
# 632         632            Aaron Hardie     20 Lakh  ALL-ROUNDER
#
#      COST IN ₹ (CR.)  Cost IN $ (000) 2021 Squad            Team
# 0               15.0           1950.0        SRH  Gujarat Titans
# ...

# %%
# Total Number of Rows (633) and columns (8)
# Total number of Players
ipl.shape
# Out:
# (633, 8)

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 633 entries, 0 to 632
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       633 non-null    int64
#  1   Player           633 non-null    object
#  2   Base Price       633 non-null    object
#  3   TYPE             633 non-null    object
#  4   COST IN ₹ (CR.)  237 non-null    float64
#  5   Cost IN $ (000)  237 non-null    float64
#  6   2021 Squad       199 non-null    object
#  7   Team             633 non-null    object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 39.7+ KB

# %%
ipl.columns
# Out:
# Index(['Unnamed: 0', 'Player', 'Base Price', 'TYPE', 'COST IN ₹ (CR.)',
#        'Cost IN $ (000)', '2021 Squad', 'Team'],
#       dtype='object')

# %%
# The column 'Unnamed: 0' is unnessesary. So remove that
ipl.drop('Unnamed: 0', axis=1, inplace= True)

# %%
ipl.columns
# Out:
# Index(['Player', 'Base Price', 'TYPE', 'COST IN ₹ (CR.)', 'Cost IN $ (000)',
#        '2021 Squad', 'Team'],
#       dtype='object')

# %%
ipl.head
# Out:
# <bound method NDFrame.head of                      Player  Base Price         TYPE  COST IN ₹ (CR.)  \
# 0               Rashid Khan  Draft Pick       BOWLER             15.0
# 1             Hardik Pandya  Draft Pick  ALL-ROUNDER             15.0
# 2           Lockie Ferguson        2 Cr       BOWLER             10.0
# 3             Rahul Tewatia     40 Lakh  ALL-ROUNDER              9.0
# 4              Shubman Gill  Draft Pick       BATTER              8.0
# ..                      ...         ...          ...              ...
# 628            Sairaj Patil     20 Lakh       BATTER              NaN
# 629              Monu Singh     20 Lakh       BOWLER              NaN
# 630  Nivethan Radhakrishnan     20 Lakh       BOWLER              NaN
# 631            Lance Morris     20 Lakh       BOWLER              NaN
# 632            Aaron Hardie     20 Lakh  ALL-ROUNDER              NaN
#
#      Cost IN $ (000) 2021 Squad            Team
# 0             1950.0        SRH  Gujarat Titans
# ...

# %%
# Find total number of null values presenting in each column
ipl.isnull().sum()
# Out:
# Player               0
# Base Price           0
# TYPE                 0
# COST IN ₹ (CR.)    396
# Cost IN $ (000)    396
# 2021 Squad         434
# Team                 0
# dtype: int64

# %%
#Checking the rows that have the 'Cost in $' as null value
ipl[ipl['Cost IN $ (000)'].isnull()]
# Out:
#                      Player Base Price         TYPE  COST IN ₹ (CR.)  \
# 237            Suresh Raina       2 Cr       BATTER              NaN
# 238             Steve Smith       2 Cr       BATTER              NaN
# 239         Shakib Al Hasan       2 Cr  ALL-ROUNDER              NaN
# 240             Amit Mishra     1.5 Cr       BOWLER              NaN
# 241             Adil Rashid       2 Cr       BOWLER              NaN
# ..                      ...        ...          ...              ...
# 628            Sairaj Patil    20 Lakh       BATTER              NaN
# 629              Monu Singh    20 Lakh       BOWLER              NaN
# 630  Nivethan Radhakrishnan    20 Lakh       BOWLER              NaN
# 631            Lance Morris    20 Lakh       BOWLER              NaN
# 632            Aaron Hardie    20 Lakh  ALL-ROUNDER              NaN
#
#      Cost IN $ (000) 2021 Squad    Team
# 237              NaN        CSK  Unsold
# 238              NaN         DC  Unsold
# ...

# %%
#Checking the rows that have the '2021 Squad' as null value
ipl[ipl['2021 Squad'].isnull()]
# Out:
#                      Player Base Price          TYPE  COST IN ₹ (CR.)  \
# 6                Yash Dayal    20 Lakh        BOWLER              3.2
# 9       Abhinav Sadarangani    20 Lakh        BATTER              2.6
# 10             Matthew Wade       2 Cr  WICKETKEEPER              2.4
# 11           Alzarri Joseph    75 Lakh        BOWLER              2.4
# 17              Varun Aaron    50 Lakh        BOWLER              0.5
# ..                      ...        ...           ...              ...
# 628            Sairaj Patil    20 Lakh        BATTER              NaN
# 629              Monu Singh    20 Lakh        BOWLER              NaN
# 630  Nivethan Radhakrishnan    20 Lakh        BOWLER              NaN
# 631            Lance Morris    20 Lakh        BOWLER              NaN
# 632            Aaron Hardie    20 Lakh   ALL-ROUNDER              NaN
#
#      Cost IN $ (000) 2021 Squad            Team
# 6              416.0        NaN  Gujarat Titans
# ...

# %%
# Replace null values with 'Not Participated' in '2021 Squad' column
ipl['2021 Squad'] = ipl['2021 Squad'].fillna('Not Participated')

# %%
# Filling the Null values with Zeros
ipl['COST IN ₹ (CR.)'] = ipl['COST IN ₹ (CR.)'].fillna(0)
ipl['Cost IN $ (000)'] = ipl['Cost IN $ (000)'].fillna(0)

# %%
ipl.head
# Out:
# <bound method NDFrame.head of                      Player  Base Price         TYPE  COST IN ₹ (CR.)  \
# 0               Rashid Khan  Draft Pick       BOWLER             15.0
# 1             Hardik Pandya  Draft Pick  ALL-ROUNDER             15.0
# 2           Lockie Ferguson        2 Cr       BOWLER             10.0
# 3             Rahul Tewatia     40 Lakh  ALL-ROUNDER              9.0
# 4              Shubman Gill  Draft Pick       BATTER              8.0
# ..                      ...         ...          ...              ...
# 628            Sairaj Patil     20 Lakh       BATTER              0.0
# 629              Monu Singh     20 Lakh       BOWLER              0.0
# 630  Nivethan Radhakrishnan     20 Lakh       BOWLER              0.0
# 631            Lance Morris     20 Lakh       BOWLER              0.0
# 632            Aaron Hardie     20 Lakh  ALL-ROUNDER              0.0
#
#      Cost IN $ (000)        2021 Squad            Team
# ...

# %%
ipl.head()
# Out:
#             Player  Base Price         TYPE  COST IN ₹ (CR.)  Cost IN $ (000)  \
# 0      Rashid Khan  Draft Pick       BOWLER             15.0           1950.0
# 1    Hardik Pandya  Draft Pick  ALL-ROUNDER             15.0           1950.0
# 2  Lockie Ferguson        2 Cr       BOWLER             10.0           1300.0
# 3    Rahul Tewatia     40 Lakh  ALL-ROUNDER              9.0           1170.0
# 4     Shubman Gill  Draft Pick       BATTER              8.0           1040.0
#
#   2021 Squad            Team
# 0        SRH  Gujarat Titans
# 1         MI  Gujarat Titans
# 2        KKR  Gujarat Titans
# 3         RR  Gujarat Titans
# 4        KKR  Gujarat Titans

# %%
ipl.head(700)
# Out:
#                      Player  Base Price         TYPE  COST IN ₹ (CR.)  \
# 0               Rashid Khan  Draft Pick       BOWLER             15.0
# 1             Hardik Pandya  Draft Pick  ALL-ROUNDER             15.0
# 2           Lockie Ferguson        2 Cr       BOWLER             10.0
# 3             Rahul Tewatia     40 Lakh  ALL-ROUNDER              9.0
# 4              Shubman Gill  Draft Pick       BATTER              8.0
# ..                      ...         ...          ...              ...
# 628            Sairaj Patil     20 Lakh       BATTER              0.0
# 629              Monu Singh     20 Lakh       BOWLER              0.0
# 630  Nivethan Radhakrishnan     20 Lakh       BOWLER              0.0
# 631            Lance Morris     20 Lakh       BOWLER              0.0
# 632            Aaron Hardie     20 Lakh  ALL-ROUNDER              0.0
#
#      Cost IN $ (000)        2021 Squad            Team
# 0             1950.0               SRH  Gujarat Titans
# ...

# %%
# See whether all the null values are removed
ipl.isnull().sum()
# Out:
# Player             0
# Base Price         0
# TYPE               0
# COST IN ₹ (CR.)    0
# Cost IN $ (000)    0
# 2021 Squad         0
# Team               0
# dtype: int64

# %%
# Creating a new variable called 'Teams' to store teams
teams = ipl[ipl['COST IN ₹ (CR.)']>0]['Team'].unique()
teams
# Out:
# array(['Gujarat Titans', 'Chennai Super Kings', 'Delhi Capitals',
#        'Kolkata Knight Riders', 'Punjab Kings', 'Lucknow Super Giants',
#        'Mumbai Indians', 'Royal Challengers Bangalore',
#        'Rajasthan Royals', 'Sunrisers Hyderabad'], dtype=object)

# %%
# Add a new column 'status' to the table
ipl['status'] = ipl['Team'].replace(teams, 'Sold')
ipl
# Out:
#                      Player  Base Price         TYPE  COST IN ₹ (CR.)  \
# 0               Rashid Khan  Draft Pick       BOWLER             15.0
# 1             Hardik Pandya  Draft Pick  ALL-ROUNDER             15.0
# 2           Lockie Ferguson        2 Cr       BOWLER             10.0
# 3             Rahul Tewatia     40 Lakh  ALL-ROUNDER              9.0
# 4              Shubman Gill  Draft Pick       BATTER              8.0
# ..                      ...         ...          ...              ...
# 628            Sairaj Patil     20 Lakh       BATTER              0.0
# 629              Monu Singh     20 Lakh       BOWLER              0.0
# 630  Nivethan Radhakrishnan     20 Lakh       BOWLER              0.0
# 631            Lance Morris     20 Lakh       BOWLER              0.0
# 632            Aaron Hardie     20 Lakh  ALL-ROUNDER              0.0
#
#      Cost IN $ (000)        2021 Squad            Team  status
# 0             1950.0               SRH  Gujarat Titans    Sold
# ...

# %%
# Find duplicated player values
# To get the names which have the same name, but different players
ipl[ipl['Player'].duplicated(keep=False)]
# Out:
#             Player Base Price         TYPE  COST IN ₹ (CR.)  Cost IN $ (000)  \
# 62     Lalit Yadav    20 Lakh  ALL-ROUNDER             0.65             84.5
# 240    Amit Mishra     1.5 Cr       BOWLER             0.00              0.0
# 499    Amit Mishra    20 Lakh       BOWLER             0.00              0.0
# 518  Shivam Sharma    20 Lakh  ALL-ROUNDER             0.00              0.0
# 530    Lalit Yadav    20 Lakh       BOWLER             0.00              0.0
# 537  Shubham Singh    20 Lakh  ALL-ROUNDER             0.00              0.0
# 544  Shubham Singh    20 Lakh       BOWLER             0.00              0.0
# 569  Shivam Sharma    20 Lakh  ALL-ROUNDER             0.00              0.0
#
#            2021 Squad            Team  status
# 62                 DC  Delhi Capitals    Sold
# 240                DC          Unsold  Unsold
# 499  Not Participated          Unsold  Unsold
# 518  Not Participated          Unsold  Unsold
# ...

# %%
# How many players have participated in IPL auction 2022?
ipl.shape[0]
# Out:
# 633

# %%
# How many types of players have participated?
types = ipl['TYPE'].value_counts()
types.reset_index()
# Out:
#           index  TYPE
# 0   ALL-ROUNDER   242
# 1        BOWLER   215
# 2        BATTER   112
# 3  WICKETKEEPER    64

# %%
# Pie Chart of types of players
# plt -> Malplot
# pct -> percentage
plt.pie(types.values, labels=types.index, labeldistance=1.2, autopct='%1.2f%%', shadow=True, startangle=60)
plt.title('Role of players participated', fontsize = 15)
plt.plot()
# Out:
# []

# %%
# Players sold and unsold using a bar graph

# plt.figure(figsize=(10,5))
# fig = sns.countplot(ipl['status'],palette=['Orange', 'Pink'])
# plt.xlabel('Sold or Unsold')
# plt.ylabel('Number of Players')
# plt.title('Sold vs Unsold', fontsize = 15)
# plt.plot()

# for p in fig.patches:
#     fig.annotate(format(p.get_height(), '.0f'), (p.get_x(), p.get_width()/2., p.get_height()), ha = 'center', va = 'center', xytext = (0,4), 
#                  textcoords = 'offset points')

# %%
# Players sold and unsold using a bar graph

plt.figure(figsize=(10, 5))
fig = sns.countplot(x='status', data=ipl, palette=['Orange', 'Pink'])
plt.xlabel('Sold or Unsold')
plt.ylabel('Number of Players')
plt.title('Sold vs Unsold', fontsize=15)
plt.plot()

for p in fig.patches:
    fig.annotate(format(p.get_height(), '.0f'),
                 (p.get_x() + p.get_width() / 2., p.get_height()),
                 ha='center', va='center', xytext=(0, 9),
                 textcoords='offset points')

plt.show()

# %%
# Print total sold and unsold
ipl.groupby('status')['Player'].count()
# Out:
# status
# Sold      237
# Unsold    396
# Name: Player, dtype: int64

# %%
# Total number of players bought by each team

# plt.figure(figsize = (20,10))
# fig = sns.countplot(ipl[ipl['Team']!= 'Unsold']['Team'])
# plt.xlabel('Team Names')
# plt.ylabel('Number of Players')
# plt.title('Players Bought by Each Team', fontsize=12)
# plt.xticks(rotation=70)
# plt.plot()

# for p in fig.patches:
#      fig.annotate(format(p.get_height(), '.0f'),
#                  (p.get_x() + p.get_width() / 2., p.get_height()),
#                  ha='center', va='center', xytext=(0, 4),
#                  textcoords='offset points')

# %%
# Total number of players bought by each team

plt.figure(figsize=(20, 10))
fig = sns.countplot(x='Team', data=ipl[ipl['Team'] != 'Unsold'])
plt.xlabel('Team Names')
plt.ylabel('Number of Players')
plt.title('Players Bought by Each Team', fontsize=12)
plt.xticks(rotation=70)
plt.plot()

for p in fig.patches:
    fig.annotate(format(p.get_height(), '.0f'),
                 (p.get_x() + p.get_width() / 2., p.get_height()),
                 ha='center', va='center', xytext=(0, 4),
                 textcoords='offset points')

plt.show()

# %%
ipl['retention'] = ipl['Base Price']

# %%
# Replace all the Base Price values with 'From Auction' in the 'Retention' column 
ipl['retention'].replace(['2 Cr', '40 Lakh', '20 Lakh', '1 Cr', '75 Lakh', '50 Lakh', '30 Lakh', '1.5 Cr'], 'From Auction', inplace = True)

# %%
# Treating Base Price
# Replace 'Draft Pick' value to '0' in tge 'Base Price' column

ipl['Base Price'].replace('Draft Pick', 0, inplace = True)

# %%
#ipl[ipl['Base Price'] == 'Draft Pick']
ipl.head(500)
# Out:
#               Player Base Price         TYPE  COST IN ₹ (CR.)  \
# 0        Rashid Khan          0       BOWLER             15.0
# 1      Hardik Pandya          0  ALL-ROUNDER             15.0
# 2    Lockie Ferguson       2 Cr       BOWLER             10.0
# 3      Rahul Tewatia    40 Lakh  ALL-ROUNDER              9.0
# 4       Shubman Gill          0       BATTER              8.0
# ..               ...        ...          ...              ...
# 495    Nandre Burger    20 Lakh       BOWLER              0.0
# 496       Matt Kelly    30 Lakh       BOWLER              0.0
# 497        V Koushik    20 Lakh       BOWLER              0.0
# 498    Akash Madhwal    20 Lakh       BOWLER              0.0
# 499      Amit Mishra    20 Lakh       BOWLER              0.0
#
#      Cost IN $ (000)        2021 Squad            Team  status     retention
# 0             1950.0               SRH  Gujarat Titans    Sold    Draft Pick
# ...

# %%
ipl['base_price_unit'] = ipl['Base Price'].apply(lambda x: str(x).split(' ')[-1])
ipl['base_price'] = ipl['Base Price'].apply(lambda x: str(x).split(' ')[0])

ipl['base_price'].replace('Retained', 0, inplace = True)

# %%
ipl.head()
# Out:
#             Player Base Price         TYPE  COST IN ₹ (CR.)  Cost IN $ (000)  \
# 0      Rashid Khan          0       BOWLER             15.0           1950.0
# 1    Hardik Pandya          0  ALL-ROUNDER             15.0           1950.0
# 2  Lockie Ferguson       2 Cr       BOWLER             10.0           1300.0
# 3    Rahul Tewatia    40 Lakh  ALL-ROUNDER              9.0           1170.0
# 4     Shubman Gill          0       BATTER              8.0           1040.0
#
#   2021 Squad            Team status     retention base_price_unit base_price
# 0        SRH  Gujarat Titans   Sold    Draft Pick               0          0
# 1         MI  Gujarat Titans   Sold    Draft Pick               0          0
# 2        KKR  Gujarat Titans   Sold  From Auction              Cr          2
# 3         RR  Gujarat Titans   Sold  From Auction            Lakh         40
# 4        KKR  Gujarat Titans   Sold    Draft Pick               0          0

# %%
# Total players retained and bought
ipl.groupby(['Team', 'retention'])['retention'].count()[:-1]
# Out:
# Team                         retention
# Chennai Super Kings          From Auction    21
#                              Retained         4
# Delhi Capitals               From Auction    20
#                              Retained         4
# Gujarat Titans               Draft Pick       3
#                              From Auction    19
# Kolkata Knight Riders        From Auction    21
#                              Retained         4
# Lucknow Super Giants         Draft Pick       3
#                              From Auction    19
# Mumbai Indians               From Auction    21
#                              Retained         4
# Punjab Kings                 From Auction    23
#                              Retained         2
# Rajasthan Royals             From Auction    21
#                              Retained         3
# Royal Challengers Bangalore  From Auction    19
#                              Retained         3
# Sunrisers Hyderabad          From Auction    20
# ...

# %%
# # Display the players based on different type of players in each team

# plt.figure(figsize = (20,10))
# fig = sns.countplot(ipl[ipl['Team']!= 'Unsold']['Team'], hue = ipl['TYPE'])
# plt.title('Players in Each Team')
# plt.xlabel('Team Names')
# plt.ylabel('Number of Players')
# plt.xticks(rotation=50)

# %%
# Display the players based on different type of players in each team

plt.figure(figsize=(20, 10))
fig = sns.countplot(x='Team', hue='TYPE', data=ipl[ipl['Team'] != 'Unsold'])
plt.title('Players in Each Team')
plt.xlabel('Team Names')
plt.ylabel('Number of Players')
plt.xticks(rotation=50)
plt.show()

# %%
# Highest amount spent on a single player by each team
ipl[ipl['retention']=='From Auction'].groupby(['Team'])['COST IN ₹ (CR.)'].max()[:-1].sort_values(ascending = False)
# Out:
# Team
# Mumbai Indians                 15.25
# Chennai Super Kings            14.00
# Kolkata Knight Riders          12.25
# Punjab Kings                   11.50
# Delhi Capitals                 10.75
# Royal Challengers Bangalore    10.75
# Sunrisers Hyderabad            10.75
# Gujarat Titans                 10.00
# Lucknow Super Giants           10.00
# Rajasthan Royals               10.00
# Name: COST IN ₹ (CR.), dtype: float64

# %%
# Top 20 Players retained at maximum price
ipl[ipl['retention']=='Retained'].sort_values(by = 'COST IN ₹ (CR.)', ascending = False).head(20)
# Out:
#                   Player Base Price          TYPE  COST IN ₹ (CR.)  \
# 22       Ravindra Jadeja   Retained   ALL-ROUNDER             16.0
# 47          Rishabh Pant   Retained  WICKETKEEPER             16.0
# 143         Rohit Sharma   Retained        BATTER             16.0
# 168          Virat Kohli   Retained        BATTER             15.0
# 214      Kane Williamson   Retained        BATTER             14.0
# 190         Sanju Samson   Retained  WICKETKEEPER             14.0
# 145       Jasprit Bumrah   Retained        BOWLER             12.0
# 24              MS Dhoni   Retained  WICKETKEEPER             12.0
# 96        Mayank Agarwal   Retained        BATTER             12.0
# 72         Andre Russell   Retained   ALL-ROUNDER             12.0
# 169        Glenn Maxwell   Retained   ALL-ROUNDER             11.0
# 191          Jos Buttler   Retained  WICKETKEEPER             10.0
# 49            Axar Patel   Retained   ALL-ROUNDER              9.0
# ...

# %%
# Top 5 bowlers picked by teams based on the price
ipl[(ipl['retention'] == 'From Auction') & (ipl['TYPE'] == 'BOWLER')].sort_values(by = 'COST IN ₹ (CR.)', ascending = False).head(5)
# Out:
#               Player Base Price    TYPE  COST IN ₹ (CR.)  Cost IN $ (000)  \
# 23     Deepak Chahar       2 Cr  BOWLER            14.00           1820.0
# 48    Shardul Thakur       2 Cr  BOWLER            10.75           1397.5
# 192  Prasidh Krishna       1 Cr  BOWLER            10.00           1300.0
# 2    Lockie Ferguson       2 Cr  BOWLER            10.00           1300.0
# 122       Avesh Khan    20 Lakh  BOWLER            10.00           1300.0
#
#     2021 Squad                  Team status     retention base_price_unit  \
# 23         CSK   Chennai Super Kings   Sold  From Auction              Cr
# 48         CSK        Delhi Capitals   Sold  From Auction              Cr
# 192        KKR      Rajasthan Royals   Sold  From Auction              Cr
# 2          KKR        Gujarat Titans   Sold  From Auction              Cr
# 122         DC  Lucknow Super Giants   Sold  From Auction            Lakh
#
#     base_price
# 23           2
# 48           2
# 192          1
# ...

# %%
# Top 10 batters or wicketkeepers picked by teams based on the price
# ' | ' == 'or'

ipl[(ipl['retention'] == 'From Auction') & ((ipl['TYPE'] == 'BATTER') | (ipl['TYPE'] == 'WICKETKEEPER'))].sort_values(by = 'COST IN ₹ (CR.)', ascending = False).head(10)
# Out:
#                Player Base Price          TYPE  COST IN ₹ (CR.)  \
# 144      Ishan Kishan       2 Cr  WICKETKEEPER            15.25
# 71       Shreyas Iyer       2 Cr        BATTER            12.25
# 215   Nicholas Pooran     1.5 Cr  WICKETKEEPER            10.75
# 217    Rahul Tripathi    40 Lakh        BATTER             8.50
# 193   Shimron Hetmyer     1.5 Cr        BATTER             8.50
# 100    Shikhar Dhawan       2 Cr        BATTER             8.25
# 195  Devdutt Padikkal       2 Cr        BATTER             7.75
# 173    Faf Du Plessis       2 Cr        BATTER             7.00
# 101    Jonny Bairstow     1.5 Cr  WICKETKEEPER             6.75
# 127   Quinton De Kock       2 Cr  WICKETKEEPER             6.75
#
#      Cost IN $ (000) 2021 Squad                         Team status  \
# 144           1982.5         MI               Mumbai Indians   Sold
# 71            1592.5         DC        Kolkata Knight Riders   Sold
# ...

# %%
# Top 8 All-Rounders picked by teams based on the price
ipl[(ipl['retention'] == 'From Auction') & (ipl['TYPE'] == 'ALL-ROUNDER')].sort_values(by = 'COST IN ₹ (CR.)', ascending = False).head(8)
# Out:
#                 Player Base Price         TYPE  COST IN ₹ (CR.)  \
# 97    Liam Livingstone       1 Cr  ALL-ROUNDER            11.50
# 170  Wanindu Hasaranga       1 Cr  ALL-ROUNDER            10.75
# 171      Harshal Patel       2 Cr  ALL-ROUNDER            10.75
# 99       Shahrukh Khan    40 Lakh  ALL-ROUNDER             9.00
# 3        Rahul Tewatia    40 Lakh  ALL-ROUNDER             9.00
# 124       Jason Holder     1.5 Cr  ALL-ROUNDER             8.75
# 216  Washington Sundar     1.5 Cr  ALL-ROUNDER             8.75
# 146          Tim David    40 Lakh  ALL-ROUNDER             8.25
#
#      Cost IN $ (000) 2021 Squad                         Team status  \
# 97            1495.0         RR                 Punjab Kings   Sold
# 170           1397.5        RCB  Royal Challengers Bangalore   Sold
# 171           1397.5        RCB  Royal Challengers Bangalore   Sold
# 99            1170.0       PBKS                 Punjab Kings   Sold
# ...

# %%
# Players that were part of the Last IPL season, but not in this IPL season

ipl = ipl.rename(columns = {'2021 Squad' : 'Previous Team'})

Unsold_Players = ipl[(ipl['Previous Team'] != 'Not Participated') & (ipl['Team'] == 'Unsold')][['Player', 'Previous Team']]
Unsold_Players
# Out:
#                       Player Previous Team
# 237             Suresh Raina           CSK
# 238              Steve Smith            DC
# 239          Shakib Al Hasan           KKR
# 240              Amit Mishra            DC
# 241              Adil Rashid          PBKS
# 242              Imran Tahir           CSK
# 243            Mujeeb Zadran           SRH
# 244               Adam Zampa           RCB
# 245            Rajat Patidar           RCB
# 246     Mohammed Azharuddeen           RCB
# 249             M. Siddharth            DC
# 252              Dawid Malan          PBKS
# 253              Eoin Morgan           KKR
# 254        Cheteshwar Pujara           CSK
# 255           Saurabh Tiwary            MI
# 257            Ishant Sharma            DC
# 259            Piyush Chawla            MI
# 260           Tabraiz Shamsi            RR
# 262              Sachin Baby           RCB
# 267              Virat Singh           SRH
# 269              Akash Singh            RR
# ...
